# %%
print('first_test')
# Out:
# first_test

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("buharishehu/retail-sales-dataset")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import kagglehub
#       2
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("buharishehu/retail-sales-dataset")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "buharishehu/retail-sales-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Install dependencies as needed:
#       2 # pip install kagglehub[pandas-datasets]
# ----> 3 import kagglehub
#       4 from kagglehub import KaggleDatasetAdapter
#       5
#       6 # Set the path to the file you'd like to load
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
print("2nd")
# Out:
# 2nd

# %%
from sklearn import datasets
import pandas as pd

retail_sales = pd.read_excel("/Users/sandytran/Desktop/retail_sales_dataset.xlsx")
df = pd.DataFrame(retail_sales)
print(head(df, 20))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn import datasets
#       2 import pandas as pd
#       3
#       4 retail_sales = pd.read_excel("/Users/sandytran/Desktop/retail_sales_dataset.xlsx")
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
python -m venv sklearn-env
source sklearn-env/bin/activate  # activate
pip install -U scikit-learn
# Out:
#   Cell In[9], line 1
#     python -m venv sklearn-env
#               ^
# SyntaxError: invalid syntax

# %%
pip install -U scikit-learn
# Out:
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 14.8 MB/s  0:00:00 eta 0:00:010:00:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 19.4 MB/s  0:00:00 20.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.7/22.7 MB 17.6 MB/s  0:00:01 eta 0:00:010:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [scikit-learn]0m 5/6 [scikit-learn]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.9.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License-Expression: BSD-3-Clause
# Location: /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages
# Requires: joblib, narwhals, numpy, scipy, threadpoolctl
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import datasets
import pandas as pd

retail_sales = pd.read_excel("/Users/sandytran/Desktop/retail_sales_dataset.xlsx")
df = pd.DataFrame(retail_sales)
print(head(df, 20))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 12.9 MB/s  0:00:00.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import datasets
import pandas as pd

retail_sales = pd.read("/Users/sandytran/Desktop/retail_sales_dataset.xlsx")
df = pd.DataFrame(retail_sales)
print(head(df, 20))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 from sklearn import datasets
#       2 import pandas as pd
#       3
# ----> 4 retail_sales = pd.read("/Users/sandytran/Desktop/retail_sales_dataset.xlsx")
#       5 df = pd.DataFrame(retail_sales)
#       6 print(head(df, 20))
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
from sklearn import datasets
import pandas as pd

retail_sales = pd.read_excel("retail_sales_dataset.xlsx", sheet_name="Transactions")
print(head(retail_sales, 20))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn import datasets
#       2 import pandas as pd
#       3
# ----> 4 retail_sales = pd.read_excel("retail_sales_dataset.xlsx", sheet_name="Transactions")
#       5 print(head(retail_sales, 20))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
# ...

# %%
pip install pandas openpyxl xlwings
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.1 MB/s  0:00:00m ? eta -:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 33.0 MB/s  0:00:00
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [xlwings]━━━ 4/5 [xlwings]]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install DateTime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [DateTime]━━━━━━━━━ 2/3 [DateTime]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 23.7 MB/s  0:00:00 26.0 MB/s eta 0:00:01
# Using cached contourpy-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl (293 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.9 MB/s  0:00:00 12.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 32.1 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib] 6/7 [matplotlib]ow]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#simple linear regression based on discount amount using retail_sales_dataset Excel

from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from datetime import datetime
import seaborn as sns
import numpy as np

retail_sales = pd.read_excel("/Users/sandytran/Desktop/retail_sales_dataset.xlsx", sheet_name="Transactions")
retail_sales = pd.DataFrame(retail_sales)

#split dataset to X and Y variables
#x variable is 'Discount'
X = pd.DataFrame(retail_sales.Discount)
Y = pd.DataFrame(retail_sales.Quantity)

#Perform 80/20 Data split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

#data dimension
X_train.shape, Y_train.shape
X_test.shape, Y_test.shape

#create linear regression model
model = linear_model.LinearRegression()
model.fit(X_train, Y_train)

#apply trained model to make predictions on test set
Y_pred = model.predict(X_test)

#print model performance
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))

#scatter plot
np.array(Y_test)
plt.scatter(Y_test, Y_pred)
# Out:
# Coefficients: [[0.21500115]]
# Intercept: [2.96828085]
# Mean squared error (MSE): 1.92
# Coefficient of determination (R^2): -0.00
